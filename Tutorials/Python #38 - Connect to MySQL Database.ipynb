# %% [markdown]
# # Python code to connect to MySQL Database

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host='localhost', user='root', passwd='mysql')

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test_akshay',),
#  ('world',)]

# %%
cursor.execute("use world")

# %%
cursor.execute("show tables")
cursor.fetchall()
# Out:
# [('city',), ('country',), ('countrylanguage',)]

# %%
cursor.execute("SELECT * FROM world.city")
cursor.fetchall()
# Out:
# [(1, 'Kabul', 'AFG', 'Kabol', 1780000),
#  (2, 'Qandahar', 'AFG', 'Qandahar', 237500),
#  (3, 'Herat', 'AFG', 'Herat', 186800),
#  (4, 'Mazar-e-Sharif', 'AFG', 'Balkh', 127800),
#  (5, 'Amsterdam', 'NLD', 'Noord-Holland', 731200),
#  (6, 'Rotterdam', 'NLD', 'Zuid-Holland', 593321),
#  (7, 'Haag', 'NLD', 'Zuid-Holland', 440900),
#  (8, 'Utrecht', 'NLD', 'Utrecht', 234323),
#  (9, 'Eindhoven', 'NLD', 'Noord-Brabant', 201843),
#  (10, 'Tilburg', 'NLD', 'Noord-Brabant', 193238),
#  (11, 'Groningen', 'NLD', 'Groningen', 172701),
#  (12, 'Breda', 'NLD', 'Noord-Brabant', 160398),
#  (13, 'Apeldoorn', 'NLD', 'Gelderland', 153491),
#  (14, 'Nijmegen', 'NLD', 'Gelderland', 152463),
#  (15, 'Enschede', 'NLD', 'Overijssel', 149544),
#  (16, 'Haarlem', 'NLD', 'Noord-Holland', 148772),
#  (17, 'Almere', 'NLD', 'Flevoland', 142465),
#  (18, 'Arnhem', 'NLD', 'Gelderland', 138020),
#  (19, 'Zaanstad', 'NLD', 'Noord-Holland', 135621),
#  (20, 'Â´s-Hertogenbosch', 'NLD', 'Noord-Brabant', 129170),
# ...

# %%
import pandas as pd

# %%
pd.read_sql("SELECT * FROM world.city",mydb)
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
cursor.execute("CREATE DATABASE newdb")

# %%
cursor.execute("show databases")
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('newdb',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test_akshay',),
#  ('world',)]

# %%
cursor.execute("use newdb")
cursor.execute("CREATE TABLE IF NOT EXISTS newdb.newtable(\
               id INT,\
               firstname VARCHAR(10),\
               lastname VARCHAR(10))")

# %%
cursor.execute("show tables")
cursor.fetchall()
# Out:
# [('newtable',)]

# %%
cursor.execute("INSERT INTO newdb.newtable VALUES(1,'Akshay','Daga')")

# %%
cursor.execute("INSERT INTO newdb.newtable VALUES(2,'zyx','dsfs')")
cursor.execute("INSERT INTO newdb.newtable VALUES(3,'apdaga','dumpbox')")

# %%
cursor.execute("SELECT * FROM newdb.newtable")
cursor.fetchall()
# Out:
# [(1, 'Akshay', 'Daga'), (2, 'zyx', 'dsfs'), (3, 'apdaga', 'dumpbox')]

# %%
mydb.commit()

# %%
pwd
# Out:
# 'C:\\Users\\akshay.daga\\Jupyter Notebooks'

# %%
f = open("glass.data","r")
f.read()
# Out:
# '1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1\n2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1\n3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1\n4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1\n5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1\n6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1\n7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1\n8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1\n9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1\n10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1\n11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1\n12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1\n13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1\n14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1\n15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1\n16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1\n17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1\n18,1.52196,14.36,3.85,0.89,71.36,0.15,9.15,0.00,0.00,1
# ...

# %%
cursor.execute("use newdb")
cursor.execute("CREATE TABLE IF NOT EXISTS newdb.glassdata(\
               col1 INT,\
               col2 FLOAT(10,5),\
               col3 FLOAT(10,5),\
               col4 FLOAT(10,5),\
               col5 FLOAT(10,5),\
               col6 FLOAT(10,5),\
               col7 FLOAT(10,5),\
               col8 FLOAT(10,5),\
               col9 FLOAT(10,5),\
               col10 FLOAT(10,5),\
               col11 INT)")

# %%
cursor.execute("show tables")
cursor.fetchall()
# Out:
# [('glassdata',), ('newtable',)]

# %%
import csv

# %%
with open("glass.data","r") as f:
    glass_data = csv.reader(f, delimiter = '\n')
    for line in glass_data:
        #print(line)
        #print(type(line[0]))
        print(line[0])
# Out:
# 1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1
# 2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1
# 3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1
# 4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1
# 5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1
# 6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1
# 7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1
# 8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1
# 9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1
# 10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1
# 11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1
# 12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1
# 13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1
# 14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1
# 15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1
# 16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1
# 17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1
# ...

# %%
with open("glass.data","r") as f:
    glass_data = csv.reader(f, delimiter = '\n')
    for line in glass_data:
        #print(line)
        cursor.execute(f"INSERT INTO newdb.glassdata VALUES({line[0]})")

# %%
cursor.execute("SELECT * FROM newdb.glassdata")
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
mydb.commit()

# %%
cursor.execute("SELECT * FROM newdb.glassdata WHERE col1=2")
cursor.fetchall()
# Out:
# [(2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1)]

# %%
cursor.execute("UPDATE newdb.glassdata SET col3 = 17.77 WHERE col1 = 2")

# %%
cursor.execute("SELECT * FROM newdb.glassdata WHERE col1=2")
cursor.fetchall()
# Out:
# [(2, 1.51761, 17.77, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1)]

# %%
mydb.commit()

# %%
cursor.execute("DELETE FROM newdb.glassdata WHERE col1=2")

# %%
cursor.execute("SELECT * FROM newdb.glassdata WHERE col1=2")
cursor.fetchall()
# Out:
# []

# %%
mydb.commit()

# %%
cursor.execute("SELECT col2, COUNT(col1) FROM newdb.glassdata \
GROUP BY col2 ORDER BY col2 desc")
cursor.fetchall()
# Out:
# [(1.53393, 1),
#  (1.53125, 1),
#  (1.52777, 1),
#  (1.52739, 1),
#  (1.52725, 1),
#  (1.52667, 1),
#  (1.52664, 1),
#  (1.52614, 1),
#  (1.52475, 1),
#  (1.5241, 1),
#  (1.52369, 1),
#  (1.52365, 1),
#  (1.5232, 1),
#  (1.52315, 1),
#  (1.523, 1),
#  (1.52247, 1),
#  (1.52227, 1),
#  (1.52223, 1),
#  (1.52222, 1),
#  (1.52213, 2),
#  (1.52211, 1),
#  (1.5221, 1),
#  (1.52196, 1),
#  (1.52177, 2),
#  (1.52172, 2),
#  (1.52171, 1),
#  (1.52152, 3),
#  (1.52151, 1),
#  (1.52127, 1),
#  (1.52121, 1),
#  (1.52119, 1),
#  (1.52101, 1),
#  (1.52099, 1),
#  (1.52081, 1),
#  (1.52068, 1),
#  (1.52065, 1),
#  (1.52058, 1),
#  (1.52043, 1),
#  (1.5202, 1),
#  (1.51994, 1),
#  (1.51977, 1),
#  (1.51969, 2),
#  (1.51966, 1),
#  (1.51937, 1),
#  (1.51934, 1),
#  (1.51926, 1),
#  (1.51918, 1),
#  (1.51916, 1),
#  (1.51915, 1),
#  (1.51911, 1),
#  (1.51909, 1),
#  (1.51905, 2),
#  (1.519, 1),
#  (1.51898, 1),
#  (1.51892, 1),
#  (1.51888, 1),
#  (1.51872, 1),
#  (1.51869, 1),
#  (1.5186, 1),
# ...

# %%
cursor.execute("DROP TABLE newdb.glassdata")

# %%
mydb.commit()

# %%
cursor.execute("DROP DATABASE newdb")

# %%
mydb.commit()

# %%
mydb.close()
